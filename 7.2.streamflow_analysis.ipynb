# %%
import pandas as pd

# %%
css_folder = r"Z:\PhD_Datasets&Analysis\Info_Inputs\Streamflow_Stations\Climate_Sensitive_Stations-GRDC"

filtered_css = pd.read_csv(css_folder + "//CSS_FINAL_SELECTION_WITH_ALL.csv") # Save file for possible further analysis
filtered_css
# Out:
#                                station_name  station_no  station_id  \
# 0                       ABOVE BOULEAU CREEK     4215070     1069050
# 1               ABOVE CHENEY RESERVOIRE, KS     4125110     1069620
# 2                      ABOVE FORT MCPHERSON     4208040     1068040
# 3                         ABOVE HAMBURG, IA     4122160     1068596
# 4    ABOVE HIGHWAY NO. 8 (DEMPSTER HIGHWAY)     4208070     1068049
# ..                                      ...         ...         ...
# 783               WOODFORDS, CA (WEST FORK)     4118100     1068421
# 784                                 XAMBIOA     3649418     1071023
# 785                               XAVANTINA     3649617     1074892
# 786                      YADKIN COLLEGE, NC     4148321     1069484
# 787                                    ZOZA     6150400     1074154
#
#      station_latitude  station_longitude station_status  \
# 0           50.212223        -119.538610         Active
# ...

# %%
monthly_folder = css_folder + "\\2025-02-13_17-18_Monthly\_DataFrames"

monthly_df = pd.read_csv(monthly_folder + "//Joined_Monthly_Sts_DFs.csv", index_col="YYYY-MM")
monthly_df
# Out:
#          3617110  3617811  3617812  3617814  3618051  3618052  3618500  \
# YYYY-MM
# 1958-01      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1958-02      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1958-03      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1958-04      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1958-05      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...          ...      ...      ...      ...      ...      ...      ...
# 2023-08      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2023-09      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2023-10      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2023-11      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2023-12      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#          3618700  3618711  3618720  ...  6742701  6744200  6744500  6830101  \
# ...
