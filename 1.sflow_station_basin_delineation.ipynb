# %%
# If not installed, run this cell. It is needed for watershed delineation
#!pip install pysheds
#!pip show pysheds

# %%
# If not installed, run this cell. It is needed for manipulating spatial dataframes
#!pip install geopandas
#!pip show geopandas

# %%
from pysheds.grid import Grid
import matplotlib.pyplot as plt
import matplotlib.colors as colors

from shapely.geometry import LineString
import geopandas as gpd
import pandas as pd

# %%
# Read station catalogue file
csv_folder = r"Z:\PhD_Datasets&Analysis\Info_Inputs\Streamflow_Stations"
csv_file = "Stations_Catalogue.csv"
csv_path = csv_folder + "\\" + csv_file
df_sts = pd.read_csv(csv_path)
df_sts
# Out:
#          ID                                            STATION SUFIX  \
# 0  07374525  USGS 07374525 Mississippi River at Belle Chass...  MISS
# 1        23                                           Santiago  ULUA
# 2  17050001                                             Obidos  AMZN
# 3   1662100                                            Dongola  NILE
# 4   2181900                                             Datong  YNGZ
# 5  A4261110      River Murray downstream Morgan (AMTD 316.5km)  MUDA
# 6   6742900                                      Ceatal Izmail  DABE
# 7     42055                                          Smederevo  DABE
#
#             BASIN        LAT        LONG
# 0     Mississippi  29.857145  -89.977850
# 1            Ulua  15.297001  -87.928217
# 2          Amazon  -1.947222  -55.511108
# 3            Nile  19.186000   30.489500
# 4         Yangtze  30.770000  117.620000
# 5  Murray-Darling -34.055059  139.685774
# 6          Danube  45.216667   28.716657
# ...
